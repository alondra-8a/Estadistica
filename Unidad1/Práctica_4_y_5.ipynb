# %% [markdown]
# <a href="https://colab.research.google.com/github/alondra-8a/Estadistica/blob/main/Unidad1/Pr%C3%A1ctica_4_y_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Unidad 1 Práctica 4

# %% [markdown]
# Facilitador: Dr José Gabriel Rodríguez Rivas
#
# Alumna: Alondra Viridiana Ochoa Ibáñez

# %% [markdown]
#  **Tablas** **de** **frecuencia**

# %%
import random

# %%
edades = []
for i in range (100):
  numero_aleatorio = random.randint(18,70) #antes de usar un random, importar la librería antes
  edades.append(numero_aleatorio)
print(edades)
# Out:
# [35, 63, 33, 52, 48, 30, 25, 70, 37, 29, 43, 56, 37, 51, 28, 23, 62, 62, 34, 54, 32, 28, 31, 48, 66, 58, 38, 24, 56, 30, 25, 44, 25, 52, 65, 34, 24, 30, 54, 50, 66, 22, 21, 59, 56, 28, 26, 38, 44, 69, 30, 51, 52, 32, 48, 51, 58, 39, 38, 50, 18, 24, 29, 25, 22, 45, 18, 40, 62, 28, 25, 33, 35, 31, 66, 35, 25, 70, 66, 45, 52, 49, 67, 36, 41, 46, 21, 49, 36, 64, 21, 66, 21, 55, 36, 19, 42, 58, 66, 62]

# %%
import pandas as pd

# %%
df = pd.DataFrame(edades,columns=["Edad"])
df.head()
# Out:
#    Edad
# 0    35
# 1    63
# 2    33
# 3    52
# 4    48

# %%
tabla_frecuencias = df['Edad'].value_counts().reset_index()
tabla_frecuencias.columns = ['Edad', "Frecuencia"]
tabla_frecuencias = tabla_frecuencias.sort_values(by='Edad')

print("Tabla de distribución de frecuencias:")
tabla_frecuencias
# Out:
# Tabla de distribución de frecuencias:
#     Edad  Frecuencia
# 16    18           2
# 34    19           1
# 3     21           4
# 18    22           2
# 40    23           1
# 10    24           3
# 0     25           6
# 39    26           1
# 6     28           4
# 23    29           2
# 4     30           4
# 24    31           2
# 25    32           2
# 17    33           2
# 27    34           2
# 7     35           3
# 9     36           3
# 22    37           2
# 12    38           3
# 37    39           1
# 36    40           1
# 32    41           1
# 44    42           1
# 43    43           1
# 21    44           2
# 28    45           2
# 31    46           1
# 14    48           3
# 20    49           2
# 19    50           2
# 8     51           3
# 2     52           4
# 26    54           2
# 29    55           1
# 13    56           3
# 11    58           3
# 35    59           1
# 5     62           4
# 42    63           1
# 30    64           1
# 41    65           1
# 1     66           6
# 33    67           1
# 38    69           1
# 15    70           2

# %%
tabla_frecuencias['Frec Relativa'] = tabla_frecuencias['Frecuencia'] / 100
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frec Relativa
# 16    18           2           0.02
# 34    19           1           0.01
# 3     21           4           0.04
# 18    22           2           0.02
# 40    23           1           0.01
# 10    24           3           0.03
# 0     25           6           0.06
# 39    26           1           0.01
# 6     28           4           0.04
# 23    29           2           0.02
# 4     30           4           0.04
# 24    31           2           0.02
# 25    32           2           0.02
# 17    33           2           0.02
# 27    34           2           0.02
# 7     35           3           0.03
# 9     36           3           0.03
# 22    37           2           0.02
# 12    38           3           0.03
# 37    39           1           0.01
# 36    40           1           0.01
# 32    41           1           0.01
# 44    42           1           0.01
# 43    43           1           0.01
# 21    44           2           0.02
# 28    45           2           0.02
# 31    46           1           0.01
# 14    48           3           0.03
# 20    49           2           0.02
# 19    50           2           0.02
# 8     51           3           0.03
# 2     52           4           0.04
# 26    54           2           0.02
# 29    55           1           0.01
# 13    56           3           0.03
# 11    58           3           0.03
# 35    59           1           0.01
# 5     62           4           0.04
# 42    63           1           0.01
# 30    64           1           0.01
# 41    65           1           0.01
# 1     66           6           0.06
# 33    67           1           0.01
# 38    69           1           0.01
# 15    70           2           0.02

# %%
tabla_frecuencias['Frec Porcentual'] = tabla_frecuencias ['Frecuencia'] / 100 * 100
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frec Relativa  Frec Porcentual
# 16    18           2           0.02              2.0
# 34    19           1           0.01              1.0
# 3     21           4           0.04              4.0
# 18    22           2           0.02              2.0
# 40    23           1           0.01              1.0
# 10    24           3           0.03              3.0
# 0     25           6           0.06              6.0
# 39    26           1           0.01              1.0
# 6     28           4           0.04              4.0
# 23    29           2           0.02              2.0
# 4     30           4           0.04              4.0
# 24    31           2           0.02              2.0
# 25    32           2           0.02              2.0
# 17    33           2           0.02              2.0
# 27    34           2           0.02              2.0
# 7     35           3           0.03              3.0
# 9     36           3           0.03              3.0
# 22    37           2           0.02              2.0
# 12    38           3           0.03              3.0
# 37    39           1           0.01              1.0
# 36    40           1           0.01              1.0
# 32    41           1           0.01              1.0
# 44    42           1           0.01              1.0
# 43    43           1           0.01              1.0
# 21    44           2           0.02              2.0
# 28    45           2           0.02              2.0
# 31    46           1           0.01              1.0
# 14    48           3           0.03              3.0
# 20    49           2           0.02              2.0
# 19    50           2           0.02              2.0
# 8     51           3           0.03              3.0
# 2     52           4           0.04              4.0
# 26    54           2           0.02              2.0
# 29    55           1           0.01              1.0
# 13    56           3           0.03              3.0
# 11    58           3           0.03              3.0
# 35    59           1           0.01              1.0
# 5     62           4           0.04              4.0
# 42    63           1           0.01              1.0
# 30    64           1           0.01              1.0
# 41    65           1           0.01              1.0
# 1     66           6           0.06              6.0
# 33    67           1           0.01              1.0
# 38    69           1           0.01              1.0
# 15    70           2           0.02              2.0

# %%
tabla_frecuencias['Frec Acomulada'] = tabla_frecuencias ['Frecuencia'].cumsum()
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frec Relativa  Frec Porcentual  Frec Acomulada
# 16    18           2           0.02              2.0               2
# 34    19           1           0.01              1.0               3
# 3     21           4           0.04              4.0               7
# 18    22           2           0.02              2.0               9
# 40    23           1           0.01              1.0              10
# 10    24           3           0.03              3.0              13
# 0     25           6           0.06              6.0              19
# 39    26           1           0.01              1.0              20
# 6     28           4           0.04              4.0              24
# 23    29           2           0.02              2.0              26
# 4     30           4           0.04              4.0              30
# 24    31           2           0.02              2.0              32
# 25    32           2           0.02              2.0              34
# 17    33           2           0.02              2.0              36
# 27    34           2           0.02              2.0              38
# 7     35           3           0.03              3.0              41
# 9     36           3           0.03              3.0              44
# 22    37           2           0.02              2.0              46
# 12    38           3           0.03              3.0              49
# 37    39           1           0.01              1.0              50
# 36    40           1           0.01              1.0              51
# 32    41           1           0.01              1.0              52
# 44    42           1           0.01              1.0              53
# 43    43           1           0.01              1.0              54
# 21    44           2           0.02              2.0              56
# 28    45           2           0.02              2.0              58
# 31    46           1           0.01              1.0              59
# 14    48           3           0.03              3.0              62
# 20    49           2           0.02              2.0              64
# 19    50           2           0.02              2.0              66
# 8     51           3           0.03              3.0              69
# 2     52           4           0.04              4.0              73
# 26    54           2           0.02              2.0              75
# 29    55           1           0.01              1.0              76
# 13    56           3           0.03              3.0              79
# 11    58           3           0.03              3.0              82
# 35    59           1           0.01              1.0              83
# 5     62           4           0.04              4.0              87
# 42    63           1           0.01              1.0              88
# 30    64           1           0.01              1.0              89
# 41    65           1           0.01              1.0              90
# 1     66           6           0.06              6.0              96
# 33    67           1           0.01              1.0              97
# 38    69           1           0.01              1.0              98
# 15    70           2           0.02              2.0             100

# %% [markdown]
# ##Regla de sturges
#
#
# - La regla sirve para calcular el número de clases idoneo en la que se debe dividir un conjunto de datos

# %%
import math

# %%
print(edades)
# Out:
# [35, 63, 33, 52, 48, 30, 25, 70, 37, 29, 43, 56, 37, 51, 28, 23, 62, 62, 34, 54, 32, 28, 31, 48, 66, 58, 38, 24, 56, 30, 25, 44, 25, 52, 65, 34, 24, 30, 54, 50, 66, 22, 21, 59, 56, 28, 26, 38, 44, 69, 30, 51, 52, 32, 48, 51, 58, 39, 38, 50, 18, 24, 29, 25, 22, 45, 18, 40, 62, 28, 25, 33, 35, 31, 66, 35, 25, 70, 66, 45, 52, 49, 67, 36, 41, 46, 21, 49, 36, 64, 21, 66, 21, 55, 36, 19, 42, 58, 66, 62]

# %%
df = pd.DataFrame({'Edad':edades})
df
# Out:
#     Edad
# 0     35
# 1     63
# 2     33
# 3     52
# 4     48
# ..   ...
# 95    19
# 96    42
# 97    58
# 98    66
# 99    62
#
# [100 rows x 1 columns]

# %%
n = len(edades)
K = int(1 + math.log2(100) )
print("Valor de n = ", n, "\nNúmero de intervalos =", K)
#len da la longitud
# Out:
# Valor de n =  100
# Número de intervalos = 7

# %%
tabla_frecuencia = pd.cut(df['Edad'], bins= K, include_lowest = True).value_counts().reset_index()
tabla_frecuencia.columns = ['Clase','Frec']
tabla_frecuencia
# Out:
#               Clase  Frec
# 0  (17.947, 25.429]    19
# 1  (32.857, 40.286]    17
# 2  (47.714, 55.143]    17
# 3  (25.429, 32.857]    15
# 4    (62.571, 70.0]    13
# 5  (55.143, 62.571]    11
# 6  (40.286, 47.714]     8

# %%
tabla_frecuencia = tabla_frecuencia.sort_values(by='Clase')
tabla_frecuencia
# Out:
#               Clase  Frec
# 0  (17.947, 25.429]    19
# 3  (25.429, 32.857]    15
# 1  (32.857, 40.286]    17
# 6  (40.286, 47.714]     8
# 2  (47.714, 55.143]    17
# 5  (55.143, 62.571]    11
# 4    (62.571, 70.0]    13

# %%
tabla_frecuencia["Frec Rel"] = tabla_frecuencia["Frec"] / n
tabla_frecuencia["Frec Porc"] = tabla_frecuencia["Frec"] /n * 100
tabla_frecuencia["Frec Ac"] = tabla_frecuencia["Frec"].cumsum()
tabla_frecuencia ["Frec Rel Ac"] = tabla_frecuencia["Frec Rel"].cumsum()
tabla_frecuencia["Frec Porc Ac"] = tabla_frecuencia["Frec Porc"].cumsum

print(tabla_frecuencias)
# Out:
#     Edad  Frecuencia  Frec Relativa  Frec Porcentual  Frec Acomulada
# 16    18           2           0.02              2.0               2
# 34    19           1           0.01              1.0               3
# 3     21           4           0.04              4.0               7
# 18    22           2           0.02              2.0               9
# 40    23           1           0.01              1.0              10
# 10    24           3           0.03              3.0              13
# 0     25           6           0.06              6.0              19
# 39    26           1           0.01              1.0              20
# 6     28           4           0.04              4.0              24
# 23    29           2           0.02              2.0              26
# 4     30           4           0.04              4.0              30
# 24    31           2           0.02              2.0              32
# 25    32           2           0.02              2.0              34
# 17    33           2           0.02              2.0              36
# 27    34           2           0.02              2.0              38
# 7     35           3           0.03              3.0              41
# 9     36           3           0.03              3.0              44
# 22    37           2           0.02              2.0              46
# 12    38           3           0.03              3.0              49
# 37    39           1           0.01              1.0              50
# 36    40           1           0.01              1.0              51
# 32    41           1           0.01              1.0              52
# 44    42           1           0.01              1.0              53
# 43    43           1           0.01              1.0              54
# 21    44           2           0.02              2.0              56
# 28    45           2           0.02              2.0              58
# 31    46           1           0.01              1.0              59
# 14    48           3           0.03              3.0              62
# 20    49           2           0.02              2.0              64
# 19    50           2           0.02              2.0              66
# 8     51           3           0.03              3.0              69
# 2     52           4           0.04              4.0              73
# 26    54           2           0.02              2.0              75
# 29    55           1           0.01              1.0              76
# 13    56           3           0.03              3.0              79
# 11    58           3           0.03              3.0              82
# 35    59           1           0.01              1.0              83
# 5     62           4           0.04              4.0              87
# 42    63           1           0.01              1.0              88
# 30    64           1           0.01              1.0              89
# 41    65           1           0.01              1.0              90
# 1     66           6           0.06              6.0              96
# 33    67           1           0.01              1.0              97
# 38    69           1           0.01              1.0              98
# 15    70           2           0.02              2.0             100

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(edades,alpha =0.5, bins = 20) #bins es para los contenedores
plt.title("Histograma de edades basado en la funcion de matplotlibncon valores estandar")
# Out:
# Text(0.5, 1.0, 'Histograma de edades basado en la funcion de matplotlibncon valores estandar')

# %%
plt.hist(df['Edad'], bins = K, alpha = 0.5)
plt.title("Histograma de edades basado en la regla de Sturges")
plt.xlabel("Edades")
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# ##Practica 5
# ###- Diagrama de cajas y bigotesbigotes

# %%
import random

# %%
edades2 = []
for i in range (100):
  numero_aleatorio = random.randint(20,87)
  edades2.append(numero_aleatorio)

print(edades2)
# Out:
# [50, 61, 43, 21, 21, 67, 32, 78, 69, 29, 80, 32, 85, 82, 37, 35, 34, 22, 30, 30, 64, 86, 78, 49, 45, 39, 46, 37, 38, 46, 31, 46, 75, 80, 56, 79, 33, 30, 23, 64, 53, 28, 81, 40, 54, 66, 49, 23, 40, 31, 76, 62, 50, 58, 57, 71, 58, 45, 36, 76, 77, 39, 40, 86, 80, 56, 70, 60, 79, 44, 80, 78, 51, 41, 35, 60, 36, 80, 39, 38, 58, 38, 36, 86, 41, 73, 59, 49, 75, 68, 21, 45, 52, 39, 25, 34, 25, 84, 29, 78]

# %%
fig, (ax1,ax2) = plt.subplots(nrows=1, ncols=2, figsize=(9,4))
bplot= ax1.boxplot(edades,
                   vert=True,
                   patch_artist=True)
ax1.set_title("Edades Encuesta 1")

bplot2= ax2.boxplot(edades2,
                    vert=True,
                    patch_artist=True)

ax2.set_title('Edades Encuesta 2')
plt.show()

# %%
edades2.append(130)
